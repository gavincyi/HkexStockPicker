# %% [markdown]
# # Initialization

# %% [markdown]
# ### 1. Import libraries

# %%
# %matplotlib inline
import Quandl
import pandas as pd
import matplotlib.pyplot as plt
from backports import configparser
from IPython.display import clear_output

# %% [markdown]
# ### 2. Initialize general configuration items

# %%
config = configparser.ConfigParser()
config.read("HkexStockPicker.ini")

token = config['DEFAULT']['QuandlToken']
num_of_days = int(config['DEFAULT']['NumOfDays'])
num_of_pool = int(config['DEFAULT']['NumOfPool'])

# %% [markdown]
# ### 3. Initialize instrument list

# %%
instmt_config = configparser.ConfigParser()
instmt_config.read(config['DEFAULT']['InstrumentsFilePath'])
instmts = {}

for group in instmt_config.sections():
    instmts[group] = dict()
    index = instmt_config[group]['Index']
    instmt_list = instmt_config['HSI']['Instruments'].replace('[','').replace(']', '').replace('\n', '').split(',')
    instmts[group]['Index'] = index
    instmts[group]['Instruments'] = instmt_list

# %% [markdown]
# # Retrieve data

# %% [markdown]
# Initialize a dataframe for all the instrument returns.

# %%
returns = pd.DataFrame()

# %% [markdown]
# Get all the benchmark returns.

# %%
for value in instmts.values():
    index = value['Index']
    returns[index] = Quandl.get(index, rows=num_of_days, authtoken=token)["Close"].pct_change()

# %% [markdown]
# Get all the stock returns

# %%
for value in instmts.values():
    for instmt in value['Instruments']:
        print("Getting instrument %s" % instmt)
        returns[instmt] = Quandl.get(instmt, rows=num_of_days, authtoken=token)["Close"].pct_change()
clear_output()

# %% [markdown]
# Drop the columns where number of valid values is less than half the days

# %%
returns_count = returns.count()
drop_columns = returns_count[returns_count < num_of_days/2].index.tolist()
returns = returns.drop(drop_columns, axis=1)

# %%
for value in instmts.values():
    for instmt in value['Instruments']:
        if instmt in drop_columns:
            value['Instruments'].remove(instmt)

# %% [markdown]
# After getting the returns, fill all the nan values to zero, assuming no change in return in non-trading days.

# %%
returns = returns.fillna(0)

# %% [markdown]
# # Data analysis

# %% [markdown]
# ### 1. YTD Best performance

# %%
group = 'HSI'
benchmark = instmts[group]['Index']
candidates = instmts[group]['Instruments']

# %% [markdown]
# Get the best performance stocks from the return

# %%
ytd_performance = returns[candidates].sum().sort_values(ascending=False)
best = pd.DataFrame(columns=[group], data=ytd_performance.head(num_of_pool))
best_candidate = best.index.values.tolist()
best
# Out:
#                     HSI
# YAHOO/HK_0066  0.035714
# YAHOO/HK_0700  0.032250
# YAHOO/HK_0002 -0.002176
# YAHOO/HK_0823 -0.006078
# YAHOO/HK_1928 -0.021530

# %%
returns[best_candidate + [benchmark]].cumsum().plot(figsize=(10,10))

# %% [markdown]
# ### 2. Half-period comparison

# %%
group = 'HSI'
benchmark = instmts[group]['Index']
candidates = instmts[group]['Instruments']

# %% [markdown]
# Set the check-point period to halve the whole period

# %%
checkpoint_days = int(num_of_days/2)

# %% [markdown]
# Find the best performance instruments across the check-point period

# %%
ckpt_performance = returns[candidates].head(checkpoint_days).sum().sort_values(ascending=False)
ckpt_best = pd.DataFrame(columns=['%s-day'%checkpoint_days], data=ckpt_performance.head(num_of_pool))
ckpt_best_candidate = ckpt_best.index.values.tolist()
ckpt_best
# Out:
#                 110-day
# YAHOO/HK_1928  0.025144
# YAHOO/HK_0823 -0.003060
# YAHOO/HK_0006 -0.008054
# YAHOO/HK_0002 -0.017068
# YAHOO/HK_0267 -0.019868

# %% [markdown]
# Find the best performance instruments for post check-point period

# %%
after_ckpt_performance = returns[candidates].tail(-checkpoint_days).sum().sort_values(ascending=False)
after_ckpt_best = pd.DataFrame(columns=['after-%s-day'%checkpoint_days], data=after_ckpt_performance.head(num_of_pool))
after_ckpt_best_candidate = after_ckpt_best.index.values.tolist()
after_ckpt_best
# Out:
#                after-110-day
# YAHOO/HK_0066       0.100847
# YAHOO/HK_0700       0.080734
# YAHOO/HK_0002       0.014892
# YAHOO/HK_0291       0.002994
# YAHOO/HK_0883       0.000556

# %% [markdown]
# Compare the performance for checkpoint and post checkpoint period

# %%
union_candiates = list(set(ckpt_best_candidate).union(after_ckpt_best_candidate))
union_performance = pd.DataFrame()
union_performance['%s-day'%checkpoint_days] = ckpt_performance.loc[union_candiates,]
union_performance['after-%s-day'%checkpoint_days] = after_ckpt_performance.loc[union_candiates,]
union_performance['ytd'] = ytd_performance.loc[union_candiates,]
union_performance = union_performance.sort_values(by=['after-%s-day'%checkpoint_days], ascending=False)
union_performance
# Out:
#                 110-day  after-110-day       ytd
# YAHOO/HK_0066 -0.065133       0.100847  0.035714
# YAHOO/HK_0700 -0.048484       0.080734  0.032250
# YAHOO/HK_0002 -0.017068       0.014892 -0.002176
# YAHOO/HK_0291 -0.251982       0.002994 -0.248987
# YAHOO/HK_0883 -0.247646       0.000556 -0.247090
# YAHOO/HK_0823 -0.003060      -0.003018 -0.006078
# YAHOO/HK_1928  0.025144      -0.046674 -0.021530
# YAHOO/HK_0006 -0.008054      -0.081412 -0.089466
# YAHOO/HK_0267 -0.019868      -0.204509 -0.224377

# %%
returns[ckpt_best_candidate + [benchmark]].cumsum().plot(figsize=(10,10))

# %%
returns[ckpt_best_candidate + [benchmark]].tail(-checkpoint_days).cumsum().plot(figsize=(10,5))
returns[after_ckpt_best_candidate + [benchmark]].tail(-checkpoint_days).cumsum().plot(figsize=(10,5))
